# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import scipy
from pylab import rcParams

# %%
from keras import backend as K
import tensorflow as tf
from keras import optimizers, Sequential
from keras.models import Model, load_model
from keras.utils import plot_model
from keras.layers import Dense, LSTM, RepeatVector, TimeDistributed
from keras.callbacks import ModelCheckpoint, TensorBoard

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score

# %%
from keras.layers import Input, Layer, InputSpec
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers, activations, initializers, constraints
from keras.constraints import UnitNorm, Constraint

# %%
from numpy.random import seed
seed(123)

SEED = 123
DATA_SPLIT_PCT = 0.215

# %%
rcParams['figure.figsize'] = 8, 6
LABELS = ["Do not treat","Apply a treatment"]

# %%
df = pd.read_excel('/content/data ( aindefla).xlsx',header=0)
# columns = ['Location']

# %%
df.head()
# Out:
#     datetime  tempmax  tempmin  temp  dew  humidity  precip  disease
# 0 2013-01-01     10.4      5.0   8.3  5.7      84.6   0.452        0
# 1 2013-01-02     13.0      7.1   9.7  8.2      91.2   3.756        0
# 2 2013-01-03     13.0      5.4   9.4  6.9      85.1   9.683        0
# 3 2013-01-04     11.4      4.2   7.8  6.5      91.6   0.000        0
# 4 2013-01-05     14.1      4.8   8.6  6.7      88.7   0.000        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  1461 non-null   datetime64[ns]
#  1   tempmax   1461 non-null   float64
#  2   tempmin   1461 non-null   float64
#  3   temp      1461 non-null   float64
#  4   dew       1461 non-null   float64
#  5   humidity  1461 non-null   float64
#  6   precip    1461 non-null   float64
#  7   disease   1461 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 91.4 KB

# %%
df.drop('datetime', inplace=True, axis=1)

# %%
#data shifting
sign = lambda x: (1, -1)[x < 0]

def curve_shift(df, shift_by):
    '''
    This function will shift the binary labels in a dataframe.
    The curve shift will be with respect to the 1s.
    For example, if shift is -2, the following process
    will happen: if row n is labeled as 1, then
    - Make row (n+shift_by):(n+shift_by-1) = 1.
    - Remove row n.
    i.e. the labels will be shifted up to 2 rows up.
   Inputs:
    df       A pandas dataframe with a binary labeled column.
             This labeled column should be named as 'y'.
    shift_by An integer denoting the number of rows to shift.

    Output
    df       A dataframe with the binary labels shifted by shift.
    '''
    vector = df['disease'].copy()
    for s in range(abs(shift_by)):
        tmp = vector.shift(sign(shift_by))
        tmp = tmp.fillna(0)
        vector += tmp
    labelcol = 'disease'
    # Add vector to the df
    df.insert(loc=0, column=labelcol+'tmp', value=vector)
    # Remove the rows with labelcol == 1.
    df = df.drop(df[df[labelcol] == 1].index)
    # Drop labelcol and rename the tmp col as labelcol
    df = df.drop(labelcol, axis=1)
    df = df.rename(columns={labelcol+'tmp': labelcol})
    # Make the labelcol binary
    df.loc[df[labelcol] > 0, labelcol] = 1

    return df

# %%
'''
Shift the data by 2 units, equal to 4 minutes.

Test: Testing whether the shift happened correctly.
'''
print('Before shifting')  # Positive labeled rows before shifting.
one_indexes = df.index[df['disease'] == 1]
display(df.iloc[(one_indexes[0]-3):(one_indexes[0]+2), 0:5].head(n=5))

# Shift the response column y by 5 rows to do a 5 days ahead prediction.
df = curve_shift(df, shift_by = -5)

print('After shifting')  # Validating if the shift happened correctly.
display(df.iloc[(one_indexes[0]-4):(one_indexes[0]+1), 0:5].head(n=5))
# Out:
# Before shifting
#     tempmax  tempmin  temp  dew  humidity
# 70     16.0      7.3  11.9  9.4      85.4
# 71     14.1      6.1  11.3  6.9      76.0
# 72     12.1      3.7   8.1  0.0      57.4
# 73     16.0      0.2   8.3  2.4      69.3
# 74     18.1     -0.1  10.7  3.8      65.0
# After shifting
#     disease  tempmax  tempmin  temp  dew
# 69      1.0     17.0      6.7  12.6  7.3
# 70      1.0     16.0      7.3  11.9  9.4
# 71      1.0     14.1      6.1  11.3  6.9
# 72      1.0     12.1      3.7   8.1  0.0
# 74      0.0     18.1     -0.1  10.7  3.8

# %%
input_X = df.loc[:, df.columns != 'disease'].values  # converts the df to a numpy array
input_y = df['disease'].values

n_features = input_X.shape[1]  # number of features

def temporalize(X, y, lookback):
    output_X = []
    output_y = []
    for i in range(len(X)-lookback-1):
        t = []
        for j in range(1,lookback+1):
            # Gather past records upto the lookback period
            t.append(X[[(i+j+1)], :])
        output_X.append(t)
        output_y.append(y[i+lookback+1])
    return output_X, output_y

# %%
'''
Test: The 3D tensors (arrays) for LSTM are forming correctly.
'''
print('First instance of y = 1 in the original data')
display(df.iloc[(np.where(np.array(input_y) == 1)[0][0]-5):(np.where(np.array(input_y) == 1)[0][0]+1), ])

lookback = 5  # Equivalent to 10 min of past data.
# Temporalize the data
X, y = temporalize(X = input_X, y = input_y, lookback = lookback)

print('For the same instance of y = 1, we are keeping past 5 samples in the 3D predictor array, X.')
display(pd.DataFrame(np.concatenate(X[np.where(np.array(y) == 1)[0][0]], axis=0 )))
# Out:
# First instance of y = 1 in the original data
#     disease  tempmax  tempmin  temp   dew  humidity  precip
# 63      0.0     17.0     12.0  14.5   9.7      73.9   3.624
# 64      0.0     19.1     10.1  13.2  10.0      81.8  14.112
# 65      0.0     20.1     12.0  16.3  12.7      79.6   1.071
# 66      0.0     23.0     11.7  16.9  13.3      80.4   1.000
# 67      0.0     22.1     12.3  16.5  11.4      73.3   0.000
# 68      1.0     18.0      9.3  13.8   9.0      74.5   2.843
# For the same instance of y = 1, we are keeping past 5 samples in the 3D predictor array, X.
#       0     1     2     3     4       5
# 0  19.1  10.1  13.2  10.0  81.8  14.112
# 1  20.1  12.0  16.3  12.7  79.6   1.071
# 2  23.0  11.7  16.9  13.3  80.4   1.000
# 3  22.1  12.3  16.5  11.4  73.3   0.000
# 4  18.0   9.3  13.8   9.0  74.5   2.843

# %%
#Divide the data into train, valid, and test
X_train, X_test, y_train, y_test = train_test_split(np.array(X), np.array(y), test_size= 0.3, random_state=SEED)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size= 0.3, random_state=SEED)
X_train.shape

X_train_y0 = X_train[y_train==0]
X_train_y1 = X_train[y_train==1]

X_valid_y0 = X_valid[y_valid==0]
X_valid_y1 = X_valid[y_valid==1]

X_train_y0.shape
# Out:
# (704, 5, 1, 6)

# %%
#Reshaping data
X_train = X_train.reshape(X_train.shape[0], lookback, n_features)
X_train_y0 = X_train_y0.reshape(X_train_y0.shape[0], lookback, n_features)
X_train_y1 = X_train_y1.reshape(X_train_y1.shape[0], lookback, n_features)

X_test = X_test.reshape(X_test.shape[0], lookback, n_features)

X_valid = X_valid.reshape(X_valid.shape[0], lookback, n_features)
X_valid_y0 = X_valid_y0.reshape(X_valid_y0.shape[0], lookback, n_features)
X_valid_y1 = X_valid_y1.reshape(X_valid_y1.shape[0], lookback, n_features)

# %%
# Standardize the data
def flatten(X):
    '''
    Flatten a 3D array.

    Input
    X            A 3D array for lstm, where the array is sample x timesteps x features.

    Output
    flattened_X  A 2D array, sample x features.
    '''
    flattened_X = np.empty((X.shape[0], X.shape[2]))  # sample x features array.
    for i in range(X.shape[0]):
        flattened_X[i] = X[i, (X.shape[1]-1), :]
    return(flattened_X)

def scale(X, scaler):
    '''
    Scale 3D array.

    Inputs
    X            A 3D array for lstm, where the array is sample x timesteps x features.
    scaler       A scaler object, e.g., sklearn.preprocessing.StandardScaler, sklearn.preprocessing.normalize

    Output
    X            Scaled 3D array.
    '''
    for i in range(X.shape[0]):
        X[i, :, :] = scaler.transform(X[i, :, :])

    return X

# %%
# Initialize a scaler using the training data.
scaler = StandardScaler().fit(flatten(X_train_y0))
X_train_y0_scaled = scale(X_train_y0, scaler)
X_train_y1_scaled = scale(X_train_y1, scaler)
X_train_scaled = scale(X_train, scaler)

# %%
'''
Test: Check if the scaling is correct.

The test succeeds if all the column means
and variances are 0 and 1, respectively, after
flattening.
'''
a = flatten(X_train_y0_scaled)
print('colwise mean', np.mean(a, axis=0).round(6))
print('colwise variance', np.var(a, axis=0))

X_valid_scaled = scale(X_valid, scaler)
X_valid_y0_scaled = scale(X_valid_y0, scaler)

X_test_scaled = scale(X_test, scaler)
# Out:
# colwise mean [-0. -0. -0. -0.  0. -0.]
# colwise variance [1. 1. 1. 1. 1. 1.]

# %%
#LSTM Autoencoder training
timesteps =  X_train_y0_scaled.shape[1]
n_features =  X_train_y0_scaled.shape[2]
epochs = 300
batch = 32
lr = 0.001

# %%
lstm_autoencoder = Sequential()
# Encoder
lstm_autoencoder.add(LSTM(32, activation='sigmoid', input_shape=(timesteps, n_features), return_sequences=True))
lstm_autoencoder.add(LSTM(16, activation='sigmoid', return_sequences=False))
lstm_autoencoder.add(RepeatVector(timesteps))
# Decoder
lstm_autoencoder.add(LSTM(16, activation='sigmoid', return_sequences=True))
lstm_autoencoder.add(LSTM(32, activation='sigmoid', return_sequences=True))
lstm_autoencoder.add(TimeDistributed(Dense(n_features)))

lstm_autoencoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 32)             4992
#
#  lstm_1 (LSTM)               (None, 16)                3136
#
#  repeat_vector (RepeatVecto  (None, 5, 16)             0
#  r)
#
#  lstm_2 (LSTM)               (None, 5, 16)             2112
#
#  lstm_3 (LSTM)               (None, 5, 32)             6272
#
#  time_distributed (TimeDist  (None, 5, 6)              198
#  ributed)
#
# =================================================================
# Total params: 16710 (65.27 KB)
# Trainable params: 16710 (65.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(patience=10, restore_best_weights=True)

# %%
adam = optimizers.Adam(lr)
lstm_autoencoder.compile(loss='mse', optimizer= adam)

lstm_autoencoder_history = lstm_autoencoder.fit(X_train_y0_scaled, X_train_y0_scaled,
                                                epochs=epochs,
                                                batch_size=batch,
                                                validation_data=(X_valid_y0_scaled, X_valid_y0_scaled),
                                                verbose=2).history
# Out:
# Epoch 1/300
# 22/22 - 6s - loss: 1.0243 - val_loss: 0.9964 - 6s/epoch - 256ms/step
# Epoch 2/300
# 22/22 - 0s - loss: 0.9783 - val_loss: 0.9860 - 392ms/epoch - 18ms/step
# Epoch 3/300
# 22/22 - 0s - loss: 0.9772 - val_loss: 0.9700 - 228ms/epoch - 10ms/step
# Epoch 4/300
# 22/22 - 0s - loss: 0.9734 - val_loss: 0.9738 - 261ms/epoch - 12ms/step
# Epoch 5/300
# 22/22 - 0s - loss: 0.9670 - val_loss: 0.9674 - 274ms/epoch - 12ms/step
# Epoch 6/300
# 22/22 - 0s - loss: 0.9353 - val_loss: 0.8900 - 258ms/epoch - 12ms/step
# Epoch 7/300
# 22/22 - 0s - loss: 0.8457 - val_loss: 0.7698 - 263ms/epoch - 12ms/step
# Epoch 8/300
# 22/22 - 0s - loss: 0.6842 - val_loss: 0.5972 - 381ms/epoch - 17ms/step
# Epoch 9/300
# 22/22 - 0s - loss: 0.5424 - val_loss: 0.4945 - 378ms/epoch - 17ms/step
# Epoch 10/300
# 22/22 - 1s - loss: 0.4810 - val_loss: 0.4539 - 504ms/epoch - 23ms/step
# Epoch 11/300
# 22/22 - 1s - loss: 0.4543 - val_loss: 0.4361 - 521ms/epoch - 24ms/step
# Epoch 12/300
# 22/22 - 0s - loss: 0.4311 - val_loss: 0.4106 - 433ms/epoch - 20ms/step
# Epoch 13/300
# 22/22 - 0s - loss: 0.4090 - val_loss: 0.3926 - 413ms/epoch - 19ms/step
# Epoch 14/300
# 22/22 - 1s - loss: 0.3897 - val_loss: 0.3761 - 538ms/epoch - 24ms/step
# Epoch 15/300
# 22/22 - 0s - loss: 0.3743 - val_loss: 0.3617 - 451ms/epoch - 21ms/step
# Epoch 16/300
# 22/22 - 0s - loss: 0.3607 - val_loss: 0.3490 - 414ms/epoch - 19ms/step
# Epoch 17/300
# 22/22 - 1s - loss: 0.3494 - val_loss: 0.3377 - 527ms/epoch - 24ms/step
# Epoch 18/300
# 22/22 - 0s - loss: 0.3398 - val_loss: 0.3290 - 466ms/epoch - 21ms/step
# Epoch 19/300
# 22/22 - 0s - loss: 0.3322 - val_loss: 0.3207 - 465ms/epoch - 21ms/step
# Epoch 20/300
# 22/22 - 0s - loss: 0.3255 - val_loss: 0.3146 - 386ms/epoch - 18ms/step
# Epoch 21/300
# 22/22 - 0s - loss: 0.3202 - val_loss: 0.3092 - 442ms/epoch - 20ms/step
# Epoch 22/300
# 22/22 - 0s - loss: 0.3156 - val_loss: 0.3047 - 385ms/epoch - 17ms/step
# Epoch 23/300
# 22/22 - 0s - loss: 0.3122 - val_loss: 0.3000 - 442ms/epoch - 20ms/step
# Epoch 24/300
# 22/22 - 0s - loss: 0.3083 - val_loss: 0.2973 - 429ms/epoch - 19ms/step
# Epoch 25/300
# 22/22 - 1s - loss: 0.3056 - val_loss: 0.2941 - 503ms/epoch - 23ms/step
# Epoch 26/300
# 22/22 - 0s - loss: 0.3032 - val_loss: 0.2913 - 422ms/epoch - 19ms/step
# Epoch 27/300
# 22/22 - 1s - loss: 0.3010 - val_loss: 0.2894 - 752ms/epoch - 34ms/step
# Epoch 28/300
# 22/22 - 1s - loss: 0.2994 - val_loss: 0.2870 - 656ms/epoch - 30ms/step
# Epoch 29/300
# 22/22 - 1s - loss: 0.2977 - val_loss: 0.2856 - 685ms/epoch - 31ms/step
# Epoch 30/300
# 22/22 - 1s - loss: 0.2964 - val_loss: 0.2839 - 788ms/epoch - 36ms/step
# Epoch 31/300
# 22/22 - 1s - loss: 0.2952 - val_loss: 0.2832 - 587ms/epoch - 27ms/step
# Epoch 32/300
# 22/22 - 0s - loss: 0.2942 - val_loss: 0.2817 - 471ms/epoch - 21ms/step
# Epoch 33/300
# 22/22 - 0s - loss: 0.2937 - val_loss: 0.2808 - 392ms/epoch - 18ms/step
# Epoch 34/300
# 22/22 - 0s - loss: 0.2926 - val_loss: 0.2804 - 409ms/epoch - 19ms/step
# Epoch 35/300
# 22/22 - 0s - loss: 0.2919 - val_loss: 0.2794 - 459ms/epoch - 21ms/step
# Epoch 36/300
# 22/22 - 1s - loss: 0.2915 - val_loss: 0.2790 - 622ms/epoch - 28ms/step
# Epoch 37/300
# 22/22 - 1s - loss: 0.2908 - val_loss: 0.2784 - 523ms/epoch - 24ms/step
# Epoch 38/300
# 22/22 - 1s - loss: 0.2905 - val_loss: 0.2782 - 553ms/epoch - 25ms/step
# Epoch 39/300
# 22/22 - 0s - loss: 0.2900 - val_loss: 0.2781 - 422ms/epoch - 19ms/step
# Epoch 40/300
# 22/22 - 0s - loss: 0.2897 - val_loss: 0.2774 - 433ms/epoch - 20ms/step
# Epoch 41/300
# 22/22 - 1s - loss: 0.2893 - val_loss: 0.2773 - 624ms/epoch - 28ms/step
# Epoch 42/300
# 22/22 - 1s - loss: 0.2892 - val_loss: 0.2772 - 599ms/epoch - 27ms/step
# Epoch 43/300
# 22/22 - 0s - loss: 0.2888 - val_loss: 0.2765 - 297ms/epoch - 14ms/step
# Epoch 44/300
# 22/22 - 0s - loss: 0.2886 - val_loss: 0.2766 - 390ms/epoch - 18ms/step
# Epoch 45/300
# 22/22 - 0s - loss: 0.2885 - val_loss: 0.2759 - 455ms/epoch - 21ms/step
# Epoch 46/300
# 22/22 - 0s - loss: 0.2884 - val_loss: 0.2760 - 430ms/epoch - 20ms/step
# Epoch 47/300
# 22/22 - 1s - loss: 0.2882 - val_loss: 0.2759 - 584ms/epoch - 27ms/step
# Epoch 48/300
# 22/22 - 0s - loss: 0.2879 - val_loss: 0.2760 - 491ms/epoch - 22ms/step
# Epoch 49/300
# 22/22 - 0s - loss: 0.2877 - val_loss: 0.2757 - 486ms/epoch - 22ms/step
# Epoch 50/300
# 22/22 - 0s - loss: 0.2874 - val_loss: 0.2756 - 397ms/epoch - 18ms/step
# Epoch 51/300
# 22/22 - 1s - loss: 0.2873 - val_loss: 0.2754 - 517ms/epoch - 24ms/step
# Epoch 52/300
# 22/22 - 1s - loss: 0.2873 - val_loss: 0.2754 - 660ms/epoch - 30ms/step
# Epoch 53/300
# 22/22 - 1s - loss: 0.2871 - val_loss: 0.2752 - 652ms/epoch - 30ms/step
# Epoch 54/300
# 22/22 - 1s - loss: 0.2871 - val_loss: 0.2749 - 614ms/epoch - 28ms/step
# Epoch 55/300
# 22/22 - 1s - loss: 0.2868 - val_loss: 0.2751 - 555ms/epoch - 25ms/step
# Epoch 56/300
# 22/22 - 1s - loss: 0.2867 - val_loss: 0.2748 - 596ms/epoch - 27ms/step
# Epoch 57/300
# 22/22 - 0s - loss: 0.2864 - val_loss: 0.2750 - 455ms/epoch - 21ms/step
# Epoch 58/300
# 22/22 - 0s - loss: 0.2864 - val_loss: 0.2745 - 294ms/epoch - 13ms/step
# Epoch 59/300
# 22/22 - 0s - loss: 0.2862 - val_loss: 0.2752 - 245ms/epoch - 11ms/step
# Epoch 60/300
# 22/22 - 0s - loss: 0.2861 - val_loss: 0.2746 - 264ms/epoch - 12ms/step
# Epoch 61/300
# 22/22 - 0s - loss: 0.2859 - val_loss: 0.2745 - 257ms/epoch - 12ms/step
# Epoch 62/300
# 22/22 - 0s - loss: 0.2861 - val_loss: 0.2746 - 221ms/epoch - 10ms/step
# Epoch 63/300
# 22/22 - 0s - loss: 0.2857 - val_loss: 0.2742 - 256ms/epoch - 12ms/step
# Epoch 64/300
# 22/22 - 0s - loss: 0.2857 - val_loss: 0.2743 - 233ms/epoch - 11ms/step
# Epoch 65/300
# 22/22 - 0s - loss: 0.2854 - val_loss: 0.2737 - 270ms/epoch - 12ms/step
# Epoch 66/300
# 22/22 - 0s - loss: 0.2852 - val_loss: 0.2739 - 226ms/epoch - 10ms/step
# Epoch 67/300
# 22/22 - 0s - loss: 0.2856 - val_loss: 0.2741 - 235ms/epoch - 11ms/step
# Epoch 68/300
# 22/22 - 0s - loss: 0.2851 - val_loss: 0.2738 - 237ms/epoch - 11ms/step
# Epoch 69/300
# 22/22 - 0s - loss: 0.2851 - val_loss: 0.2742 - 250ms/epoch - 11ms/step
# Epoch 70/300
# 22/22 - 0s - loss: 0.2850 - val_loss: 0.2736 - 268ms/epoch - 12ms/step
# Epoch 71/300
# 22/22 - 0s - loss: 0.2848 - val_loss: 0.2741 - 230ms/epoch - 10ms/step
# Epoch 72/300
# 22/22 - 0s - loss: 0.2846 - val_loss: 0.2735 - 233ms/epoch - 11ms/step
# Epoch 73/300
# 22/22 - 0s - loss: 0.2850 - val_loss: 0.2733 - 279ms/epoch - 13ms/step
# Epoch 74/300
# 22/22 - 0s - loss: 0.2845 - val_loss: 0.2743 - 235ms/epoch - 11ms/step
# Epoch 75/300
# 22/22 - 0s - loss: 0.2846 - val_loss: 0.2735 - 262ms/epoch - 12ms/step
# Epoch 76/300
# 22/22 - 0s - loss: 0.2846 - val_loss: 0.2734 - 271ms/epoch - 12ms/step
# Epoch 77/300
# 22/22 - 0s - loss: 0.2844 - val_loss: 0.2736 - 282ms/epoch - 13ms/step
# Epoch 78/300
# 22/22 - 0s - loss: 0.2840 - val_loss: 0.2732 - 234ms/epoch - 11ms/step
# Epoch 79/300
# 22/22 - 0s - loss: 0.2847 - val_loss: 0.2735 - 265ms/epoch - 12ms/step
# Epoch 80/300
# 22/22 - 0s - loss: 0.2839 - val_loss: 0.2729 - 278ms/epoch - 13ms/step
# Epoch 81/300
# 22/22 - 0s - loss: 0.2840 - val_loss: 0.2735 - 265ms/epoch - 12ms/step
# Epoch 82/300
# 22/22 - 0s - loss: 0.2835 - val_loss: 0.2733 - 264ms/epoch - 12ms/step
# Epoch 83/300
# 22/22 - 0s - loss: 0.2834 - val_loss: 0.2724 - 277ms/epoch - 13ms/step
# Epoch 84/300
# 22/22 - 0s - loss: 0.2834 - val_loss: 0.2729 - 268ms/epoch - 12ms/step
# Epoch 85/300
# 22/22 - 0s - loss: 0.2832 - val_loss: 0.2724 - 237ms/epoch - 11ms/step
# Epoch 86/300
# 22/22 - 0s - loss: 0.2829 - val_loss: 0.2725 - 237ms/epoch - 11ms/step
# Epoch 87/300
# 22/22 - 0s - loss: 0.2829 - val_loss: 0.2726 - 266ms/epoch - 12ms/step
# Epoch 88/300
# 22/22 - 0s - loss: 0.2827 - val_loss: 0.2724 - 251ms/epoch - 11ms/step
# Epoch 89/300
# 22/22 - 0s - loss: 0.2826 - val_loss: 0.2725 - 234ms/epoch - 11ms/step
# Epoch 90/300
# 22/22 - 0s - loss: 0.2824 - val_loss: 0.2720 - 223ms/epoch - 10ms/step
# Epoch 91/300
# 22/22 - 0s - loss: 0.2820 - val_loss: 0.2724 - 224ms/epoch - 10ms/step
# Epoch 92/300
# 22/22 - 0s - loss: 0.2825 - val_loss: 0.2722 - 237ms/epoch - 11ms/step
# Epoch 93/300
# 22/22 - 0s - loss: 0.2823 - val_loss: 0.2720 - 248ms/epoch - 11ms/step
# Epoch 94/300
# 22/22 - 0s - loss: 0.2817 - val_loss: 0.2721 - 280ms/epoch - 13ms/step
# Epoch 95/300
# 22/22 - 0s - loss: 0.2818 - val_loss: 0.2716 - 382ms/epoch - 17ms/step
# Epoch 96/300
# 22/22 - 0s - loss: 0.2820 - val_loss: 0.2717 - 421ms/epoch - 19ms/step
# Epoch 97/300
# 22/22 - 0s - loss: 0.2817 - val_loss: 0.2718 - 371ms/epoch - 17ms/step
# Epoch 98/300
# 22/22 - 0s - loss: 0.2814 - val_loss: 0.2712 - 361ms/epoch - 16ms/step
# Epoch 99/300
# 22/22 - 0s - loss: 0.2813 - val_loss: 0.2714 - 375ms/epoch - 17ms/step
# Epoch 100/300
# 22/22 - 0s - loss: 0.2816 - val_loss: 0.2719 - 387ms/epoch - 18ms/step
# Epoch 101/300
# 22/22 - 0s - loss: 0.2809 - val_loss: 0.2714 - 351ms/epoch - 16ms/step
# Epoch 102/300
# 22/22 - 0s - loss: 0.2813 - val_loss: 0.2710 - 255ms/epoch - 12ms/step
# Epoch 103/300
# 22/22 - 0s - loss: 0.2805 - val_loss: 0.2710 - 257ms/epoch - 12ms/step
# Epoch 104/300
# 22/22 - 0s - loss: 0.2807 - val_loss: 0.2709 - 234ms/epoch - 11ms/step
# Epoch 105/300
# 22/22 - 0s - loss: 0.2806 - val_loss: 0.2711 - 274ms/epoch - 12ms/step
# Epoch 106/300
# 22/22 - 0s - loss: 0.2810 - val_loss: 0.2710 - 232ms/epoch - 11ms/step
# Epoch 107/300
# 22/22 - 0s - loss: 0.2802 - val_loss: 0.2706 - 235ms/epoch - 11ms/step
# Epoch 108/300
# 22/22 - 0s - loss: 0.2799 - val_loss: 0.2708 - 254ms/epoch - 12ms/step
# Epoch 109/300
# 22/22 - 0s - loss: 0.2798 - val_loss: 0.2709 - 239ms/epoch - 11ms/step
# Epoch 110/300
# 22/22 - 0s - loss: 0.2802 - val_loss: 0.2712 - 236ms/epoch - 11ms/step
# Epoch 111/300
# 22/22 - 0s - loss: 0.2803 - val_loss: 0.2708 - 252ms/epoch - 11ms/step
# Epoch 112/300
# 22/22 - 0s - loss: 0.2799 - val_loss: 0.2709 - 227ms/epoch - 10ms/step
# Epoch 113/300
# 22/22 - 0s - loss: 0.2798 - val_loss: 0.2707 - 261ms/epoch - 12ms/step
# Epoch 114/300
# 22/22 - 0s - loss: 0.2796 - val_loss: 0.2703 - 242ms/epoch - 11ms/step
# Epoch 115/300
# 22/22 - 0s - loss: 0.2789 - val_loss: 0.2702 - 257ms/epoch - 12ms/step
# Epoch 116/300
# 22/22 - 0s - loss: 0.2790 - val_loss: 0.2699 - 261ms/epoch - 12ms/step
# Epoch 117/300
# 22/22 - 0s - loss: 0.2784 - val_loss: 0.2701 - 238ms/epoch - 11ms/step
# Epoch 118/300
# 22/22 - 0s - loss: 0.2787 - val_loss: 0.2696 - 261ms/epoch - 12ms/step
# Epoch 119/300
# 22/22 - 0s - loss: 0.2785 - val_loss: 0.2709 - 232ms/epoch - 11ms/step
# Epoch 120/300
# 22/22 - 0s - loss: 0.2786 - val_loss: 0.2698 - 227ms/epoch - 10ms/step
# Epoch 121/300
# 22/22 - 0s - loss: 0.2785 - val_loss: 0.2701 - 266ms/epoch - 12ms/step
# Epoch 122/300
# 22/22 - 0s - loss: 0.2781 - val_loss: 0.2700 - 241ms/epoch - 11ms/step
# Epoch 123/300
# 22/22 - 0s - loss: 0.2782 - val_loss: 0.2696 - 227ms/epoch - 10ms/step
# Epoch 124/300
# 22/22 - 0s - loss: 0.2777 - val_loss: 0.2694 - 236ms/epoch - 11ms/step
# Epoch 125/300
# 22/22 - 0s - loss: 0.2776 - val_loss: 0.2695 - 242ms/epoch - 11ms/step
# Epoch 126/300
# 22/22 - 0s - loss: 0.2774 - val_loss: 0.2693 - 236ms/epoch - 11ms/step
# Epoch 127/300
# 22/22 - 0s - loss: 0.2773 - val_loss: 0.2692 - 230ms/epoch - 10ms/step
# Epoch 128/300
# 22/22 - 0s - loss: 0.2775 - val_loss: 0.2696 - 233ms/epoch - 11ms/step
# Epoch 129/300
# 22/22 - 0s - loss: 0.2772 - val_loss: 0.2696 - 262ms/epoch - 12ms/step
# Epoch 130/300
# 22/22 - 0s - loss: 0.2769 - val_loss: 0.2691 - 240ms/epoch - 11ms/step
# Epoch 131/300
# 22/22 - 0s - loss: 0.2769 - val_loss: 0.2688 - 216ms/epoch - 10ms/step
# Epoch 132/300
# 22/22 - 0s - loss: 0.2767 - val_loss: 0.2692 - 237ms/epoch - 11ms/step
# Epoch 133/300
# 22/22 - 0s - loss: 0.2769 - val_loss: 0.2691 - 258ms/epoch - 12ms/step
# Epoch 134/300
# 22/22 - 0s - loss: 0.2768 - val_loss: 0.2695 - 259ms/epoch - 12ms/step
# Epoch 135/300
# 22/22 - 0s - loss: 0.2769 - val_loss: 0.2694 - 232ms/epoch - 11ms/step
# Epoch 136/300
# 22/22 - 0s - loss: 0.2760 - val_loss: 0.2692 - 273ms/epoch - 12ms/step
# Epoch 137/300
# 22/22 - 0s - loss: 0.2760 - val_loss: 0.2690 - 264ms/epoch - 12ms/step
# Epoch 138/300
# 22/22 - 0s - loss: 0.2760 - val_loss: 0.2690 - 268ms/epoch - 12ms/step
# Epoch 139/300
# 22/22 - 0s - loss: 0.2758 - val_loss: 0.2691 - 236ms/epoch - 11ms/step
# Epoch 140/300
# 22/22 - 0s - loss: 0.2754 - val_loss: 0.2688 - 239ms/epoch - 11ms/step
# Epoch 141/300
# 22/22 - 0s - loss: 0.2753 - val_loss: 0.2688 - 271ms/epoch - 12ms/step
# Epoch 142/300
# 22/22 - 0s - loss: 0.2752 - val_loss: 0.2684 - 362ms/epoch - 16ms/step
# Epoch 143/300
# 22/22 - 0s - loss: 0.2759 - val_loss: 0.2693 - 353ms/epoch - 16ms/step
# Epoch 144/300
# 22/22 - 0s - loss: 0.2752 - val_loss: 0.2693 - 370ms/epoch - 17ms/step
# Epoch 145/300
# 22/22 - 0s - loss: 0.2748 - val_loss: 0.2685 - 383ms/epoch - 17ms/step
# Epoch 146/300
# 22/22 - 0s - loss: 0.2749 - val_loss: 0.2690 - 362ms/epoch - 16ms/step
# Epoch 147/300
# 22/22 - 0s - loss: 0.2751 - val_loss: 0.2685 - 366ms/epoch - 17ms/step
# Epoch 148/300
# 22/22 - 0s - loss: 0.2746 - val_loss: 0.2678 - 371ms/epoch - 17ms/step
# Epoch 149/300
# 22/22 - 0s - loss: 0.2742 - val_loss: 0.2686 - 281ms/epoch - 13ms/step
# Epoch 150/300
# 22/22 - 0s - loss: 0.2744 - val_loss: 0.2686 - 257ms/epoch - 12ms/step
# Epoch 151/300
# 22/22 - 0s - loss: 0.2742 - val_loss: 0.2683 - 238ms/epoch - 11ms/step
# Epoch 152/300
# 22/22 - 0s - loss: 0.2745 - val_loss: 0.2684 - 259ms/epoch - 12ms/step
# Epoch 153/300
# 22/22 - 0s - loss: 0.2740 - val_loss: 0.2681 - 238ms/epoch - 11ms/step
# Epoch 154/300
# 22/22 - 0s - loss: 0.2741 - val_loss: 0.2683 - 233ms/epoch - 11ms/step
# Epoch 155/300
# 22/22 - 0s - loss: 0.2739 - val_loss: 0.2684 - 258ms/epoch - 12ms/step
# Epoch 156/300
# 22/22 - 0s - loss: 0.2738 - val_loss: 0.2687 - 233ms/epoch - 11ms/step
# Epoch 157/300
# 22/22 - 0s - loss: 0.2733 - val_loss: 0.2682 - 225ms/epoch - 10ms/step
# Epoch 158/300
# 22/22 - 0s - loss: 0.2732 - val_loss: 0.2679 - 230ms/epoch - 10ms/step
# Epoch 159/300
# 22/22 - 0s - loss: 0.2731 - val_loss: 0.2687 - 227ms/epoch - 10ms/step
# Epoch 160/300
# 22/22 - 0s - loss: 0.2732 - val_loss: 0.2680 - 266ms/epoch - 12ms/step
# Epoch 161/300
# 22/22 - 0s - loss: 0.2733 - val_loss: 0.2694 - 226ms/epoch - 10ms/step
# Epoch 162/300
# 22/22 - 0s - loss: 0.2730 - val_loss: 0.2685 - 236ms/epoch - 11ms/step
# Epoch 163/300
# 22/22 - 0s - loss: 0.2730 - val_loss: 0.2682 - 220ms/epoch - 10ms/step
# Epoch 164/300
# 22/22 - 0s - loss: 0.2728 - val_loss: 0.2678 - 271ms/epoch - 12ms/step
# Epoch 165/300
# 22/22 - 0s - loss: 0.2728 - val_loss: 0.2682 - 239ms/epoch - 11ms/step
# Epoch 166/300
# 22/22 - 0s - loss: 0.2728 - val_loss: 0.2677 - 244ms/epoch - 11ms/step
# Epoch 167/300
# 22/22 - 0s - loss: 0.2726 - val_loss: 0.2688 - 256ms/epoch - 12ms/step
# Epoch 168/300
# 22/22 - 0s - loss: 0.2726 - val_loss: 0.2681 - 252ms/epoch - 11ms/step
# Epoch 169/300
# 22/22 - 0s - loss: 0.2723 - val_loss: 0.2683 - 238ms/epoch - 11ms/step
# Epoch 170/300
# 22/22 - 0s - loss: 0.2725 - val_loss: 0.2683 - 266ms/epoch - 12ms/step
# Epoch 171/300
# 22/22 - 0s - loss: 0.2724 - val_loss: 0.2680 - 257ms/epoch - 12ms/step
# Epoch 172/300
# 22/22 - 0s - loss: 0.2720 - val_loss: 0.2677 - 272ms/epoch - 12ms/step
# Epoch 173/300
# 22/22 - 0s - loss: 0.2719 - val_loss: 0.2678 - 267ms/epoch - 12ms/step
# Epoch 174/300
# 22/22 - 0s - loss: 0.2722 - val_loss: 0.2675 - 235ms/epoch - 11ms/step
# Epoch 175/300
# 22/22 - 0s - loss: 0.2719 - val_loss: 0.2674 - 225ms/epoch - 10ms/step
# Epoch 176/300
# 22/22 - 0s - loss: 0.2715 - val_loss: 0.2677 - 244ms/epoch - 11ms/step
# Epoch 177/300
# 22/22 - 0s - loss: 0.2720 - val_loss: 0.2674 - 260ms/epoch - 12ms/step
# Epoch 178/300
# 22/22 - 0s - loss: 0.2713 - val_loss: 0.2673 - 253ms/epoch - 12ms/step
# Epoch 179/300
# 22/22 - 0s - loss: 0.2713 - val_loss: 0.2677 - 239ms/epoch - 11ms/step
# Epoch 180/300
# 22/22 - 0s - loss: 0.2714 - val_loss: 0.2673 - 273ms/epoch - 12ms/step
# Epoch 181/300
# 22/22 - 0s - loss: 0.2711 - val_loss: 0.2677 - 260ms/epoch - 12ms/step
# Epoch 182/300
# 22/22 - 0s - loss: 0.2714 - val_loss: 0.2676 - 238ms/epoch - 11ms/step
# Epoch 183/300
# 22/22 - 0s - loss: 0.2716 - val_loss: 0.2677 - 222ms/epoch - 10ms/step
# Epoch 184/300
# 22/22 - 0s - loss: 0.2713 - val_loss: 0.2678 - 250ms/epoch - 11ms/step
# Epoch 185/300
# 22/22 - 0s - loss: 0.2712 - val_loss: 0.2672 - 253ms/epoch - 11ms/step
# Epoch 186/300
# 22/22 - 0s - loss: 0.2709 - val_loss: 0.2674 - 224ms/epoch - 10ms/step
# Epoch 187/300
# 22/22 - 0s - loss: 0.2711 - val_loss: 0.2676 - 270ms/epoch - 12ms/step
# Epoch 188/300
# 22/22 - 0s - loss: 0.2711 - val_loss: 0.2674 - 275ms/epoch - 13ms/step
# Epoch 189/300
# 22/22 - 0s - loss: 0.2710 - val_loss: 0.2674 - 383ms/epoch - 17ms/step
# Epoch 190/300
# 22/22 - 0s - loss: 0.2708 - val_loss: 0.2674 - 395ms/epoch - 18ms/step
# Epoch 191/300
# 22/22 - 0s - loss: 0.2707 - val_loss: 0.2672 - 372ms/epoch - 17ms/step
# Epoch 192/300
# 22/22 - 0s - loss: 0.2706 - val_loss: 0.2675 - 398ms/epoch - 18ms/step
# Epoch 193/300
# 22/22 - 0s - loss: 0.2706 - val_loss: 0.2672 - 392ms/epoch - 18ms/step
# Epoch 194/300
# 22/22 - 0s - loss: 0.2704 - val_loss: 0.2676 - 392ms/epoch - 18ms/step
# Epoch 195/300
# 22/22 - 0s - loss: 0.2706 - val_loss: 0.2674 - 380ms/epoch - 17ms/step
# Epoch 196/300
# 22/22 - 0s - loss: 0.2714 - val_loss: 0.2683 - 267ms/epoch - 12ms/step
# Epoch 197/300
# 22/22 - 0s - loss: 0.2709 - val_loss: 0.2676 - 263ms/epoch - 12ms/step
# Epoch 198/300
# 22/22 - 0s - loss: 0.2706 - val_loss: 0.2674 - 224ms/epoch - 10ms/step
# Epoch 199/300
# 22/22 - 0s - loss: 0.2703 - val_loss: 0.2670 - 235ms/epoch - 11ms/step
# Epoch 200/300
# 22/22 - 0s - loss: 0.2700 - val_loss: 0.2684 - 253ms/epoch - 12ms/step
# Epoch 201/300
# 22/22 - 0s - loss: 0.2704 - val_loss: 0.2675 - 262ms/epoch - 12ms/step
# Epoch 202/300
# 22/22 - 0s - loss: 0.2704 - val_loss: 0.2676 - 219ms/epoch - 10ms/step
# Epoch 203/300
# 22/22 - 0s - loss: 0.2703 - val_loss: 0.2673 - 237ms/epoch - 11ms/step
# Epoch 204/300
# 22/22 - 0s - loss: 0.2696 - val_loss: 0.2672 - 226ms/epoch - 10ms/step
# Epoch 205/300
# 22/22 - 0s - loss: 0.2699 - val_loss: 0.2672 - 268ms/epoch - 12ms/step
# Epoch 206/300
# 22/22 - 0s - loss: 0.2694 - val_loss: 0.2669 - 230ms/epoch - 10ms/step
# Epoch 207/300
# 22/22 - 0s - loss: 0.2696 - val_loss: 0.2668 - 260ms/epoch - 12ms/step
# Epoch 208/300
# 22/22 - 0s - loss: 0.2696 - val_loss: 0.2674 - 251ms/epoch - 11ms/step
# Epoch 209/300
# 22/22 - 0s - loss: 0.2692 - val_loss: 0.2667 - 256ms/epoch - 12ms/step
# Epoch 210/300
# 22/22 - 0s - loss: 0.2693 - val_loss: 0.2665 - 247ms/epoch - 11ms/step
# Epoch 211/300
# 22/22 - 0s - loss: 0.2694 - val_loss: 0.2667 - 255ms/epoch - 12ms/step
# Epoch 212/300
# 22/22 - 0s - loss: 0.2689 - val_loss: 0.2667 - 259ms/epoch - 12ms/step
# Epoch 213/300
# 22/22 - 0s - loss: 0.2695 - val_loss: 0.2670 - 254ms/epoch - 12ms/step
# Epoch 214/300
# 22/22 - 0s - loss: 0.2694 - val_loss: 0.2669 - 230ms/epoch - 10ms/step
# Epoch 215/300
# 22/22 - 0s - loss: 0.2690 - val_loss: 0.2667 - 236ms/epoch - 11ms/step
# Epoch 216/300
# 22/22 - 0s - loss: 0.2689 - val_loss: 0.2667 - 230ms/epoch - 10ms/step
# Epoch 217/300
# 22/22 - 0s - loss: 0.2696 - val_loss: 0.2667 - 271ms/epoch - 12ms/step
# Epoch 218/300
# 22/22 - 0s - loss: 0.2694 - val_loss: 0.2663 - 268ms/epoch - 12ms/step
# Epoch 219/300
# 22/22 - 0s - loss: 0.2688 - val_loss: 0.2684 - 234ms/epoch - 11ms/step
# Epoch 220/300
# 22/22 - 0s - loss: 0.2693 - val_loss: 0.2669 - 263ms/epoch - 12ms/step
# Epoch 221/300
# 22/22 - 0s - loss: 0.2687 - val_loss: 0.2664 - 255ms/epoch - 12ms/step
# Epoch 222/300
# 22/22 - 0s - loss: 0.2689 - val_loss: 0.2671 - 229ms/epoch - 10ms/step
# Epoch 223/300
# 22/22 - 0s - loss: 0.2690 - val_loss: 0.2667 - 237ms/epoch - 11ms/step
# Epoch 224/300
# 22/22 - 0s - loss: 0.2691 - val_loss: 0.2666 - 263ms/epoch - 12ms/step
# Epoch 225/300
# 22/22 - 0s - loss: 0.2684 - val_loss: 0.2659 - 267ms/epoch - 12ms/step
# Epoch 226/300
# 22/22 - 0s - loss: 0.2684 - val_loss: 0.2668 - 259ms/epoch - 12ms/step
# Epoch 227/300
# 22/22 - 0s - loss: 0.2685 - val_loss: 0.2663 - 261ms/epoch - 12ms/step
# Epoch 228/300
# 22/22 - 0s - loss: 0.2683 - val_loss: 0.2665 - 232ms/epoch - 11ms/step
# Epoch 229/300
# 22/22 - 0s - loss: 0.2695 - val_loss: 0.2663 - 276ms/epoch - 13ms/step
# Epoch 230/300
# 22/22 - 0s - loss: 0.2684 - val_loss: 0.2658 - 222ms/epoch - 10ms/step
# Epoch 231/300
# 22/22 - 0s - loss: 0.2679 - val_loss: 0.2657 - 223ms/epoch - 10ms/step
# Epoch 232/300
# 22/22 - 0s - loss: 0.2679 - val_loss: 0.2657 - 268ms/epoch - 12ms/step
# Epoch 233/300
# 22/22 - 0s - loss: 0.2678 - val_loss: 0.2658 - 265ms/epoch - 12ms/step
# Epoch 234/300
# 22/22 - 0s - loss: 0.2680 - val_loss: 0.2661 - 262ms/epoch - 12ms/step
# Epoch 235/300
# 22/22 - 0s - loss: 0.2677 - val_loss: 0.2654 - 371ms/epoch - 17ms/step
# Epoch 236/300
# 22/22 - 0s - loss: 0.2674 - val_loss: 0.2651 - 404ms/epoch - 18ms/step
# Epoch 237/300
# 22/22 - 0s - loss: 0.2676 - val_loss: 0.2651 - 398ms/epoch - 18ms/step
# Epoch 238/300
# 22/22 - 0s - loss: 0.2673 - val_loss: 0.2652 - 389ms/epoch - 18ms/step
# Epoch 239/300
# 22/22 - 0s - loss: 0.2677 - val_loss: 0.2656 - 402ms/epoch - 18ms/step
# Epoch 240/300
# 22/22 - 0s - loss: 0.2675 - val_loss: 0.2651 - 388ms/epoch - 18ms/step
# Epoch 241/300
# 22/22 - 0s - loss: 0.2673 - val_loss: 0.2653 - 397ms/epoch - 18ms/step
# Epoch 242/300
# 22/22 - 0s - loss: 0.2674 - val_loss: 0.2649 - 318ms/epoch - 14ms/step
# Epoch 243/300
# 22/22 - 0s - loss: 0.2670 - val_loss: 0.2650 - 247ms/epoch - 11ms/step
# Epoch 244/300
# 22/22 - 0s - loss: 0.2673 - val_loss: 0.2645 - 263ms/epoch - 12ms/step
# Epoch 245/300
# 22/22 - 0s - loss: 0.2667 - val_loss: 0.2648 - 286ms/epoch - 13ms/step
# Epoch 246/300
# 22/22 - 0s - loss: 0.2667 - val_loss: 0.2647 - 272ms/epoch - 12ms/step
# Epoch 247/300
# 22/22 - 0s - loss: 0.2668 - val_loss: 0.2646 - 273ms/epoch - 12ms/step
# Epoch 248/300
# 22/22 - 0s - loss: 0.2672 - val_loss: 0.2643 - 299ms/epoch - 14ms/step
# Epoch 249/300
# 22/22 - 0s - loss: 0.2667 - val_loss: 0.2645 - 291ms/epoch - 13ms/step
# Epoch 250/300
# 22/22 - 0s - loss: 0.2667 - val_loss: 0.2646 - 235ms/epoch - 11ms/step
# Epoch 251/300
# 22/22 - 0s - loss: 0.2670 - val_loss: 0.2644 - 283ms/epoch - 13ms/step
# Epoch 252/300
# 22/22 - 0s - loss: 0.2663 - val_loss: 0.2638 - 299ms/epoch - 14ms/step
# Epoch 253/300
# 22/22 - 0s - loss: 0.2663 - val_loss: 0.2640 - 271ms/epoch - 12ms/step
# Epoch 254/300
# 22/22 - 0s - loss: 0.2658 - val_loss: 0.2642 - 281ms/epoch - 13ms/step
# Epoch 255/300
# 22/22 - 0s - loss: 0.2658 - val_loss: 0.2636 - 251ms/epoch - 11ms/step
# Epoch 256/300
# 22/22 - 0s - loss: 0.2666 - val_loss: 0.2644 - 289ms/epoch - 13ms/step
# Epoch 257/300
# 22/22 - 0s - loss: 0.2659 - val_loss: 0.2635 - 255ms/epoch - 12ms/step
# Epoch 258/300
# 22/22 - 0s - loss: 0.2658 - val_loss: 0.2641 - 263ms/epoch - 12ms/step
# Epoch 259/300
# 22/22 - 0s - loss: 0.2662 - val_loss: 0.2637 - 245ms/epoch - 11ms/step
# Epoch 260/300
# 22/22 - 0s - loss: 0.2655 - val_loss: 0.2632 - 263ms/epoch - 12ms/step
# Epoch 261/300
# 22/22 - 0s - loss: 0.2656 - val_loss: 0.2628 - 248ms/epoch - 11ms/step
# Epoch 262/300
# 22/22 - 0s - loss: 0.2655 - val_loss: 0.2630 - 234ms/epoch - 11ms/step
# Epoch 263/300
# 22/22 - 0s - loss: 0.2653 - val_loss: 0.2633 - 258ms/epoch - 12ms/step
# Epoch 264/300
# 22/22 - 0s - loss: 0.2654 - val_loss: 0.2627 - 286ms/epoch - 13ms/step
# Epoch 265/300
# 22/22 - 0s - loss: 0.2651 - val_loss: 0.2630 - 265ms/epoch - 12ms/step
# Epoch 266/300
# 22/22 - 0s - loss: 0.2654 - val_loss: 0.2624 - 253ms/epoch - 12ms/step
# Epoch 267/300
# 22/22 - 0s - loss: 0.2650 - val_loss: 0.2626 - 254ms/epoch - 12ms/step
# Epoch 268/300
# 22/22 - 0s - loss: 0.2645 - val_loss: 0.2620 - 243ms/epoch - 11ms/step
# Epoch 269/300
# 22/22 - 0s - loss: 0.2641 - val_loss: 0.2618 - 268ms/epoch - 12ms/step
# Epoch 270/300
# 22/22 - 0s - loss: 0.2641 - val_loss: 0.2615 - 272ms/epoch - 12ms/step
# Epoch 271/300
# 22/22 - 0s - loss: 0.2643 - val_loss: 0.2616 - 260ms/epoch - 12ms/step
# Epoch 272/300
# 22/22 - 0s - loss: 0.2644 - val_loss: 0.2617 - 275ms/epoch - 13ms/step
# Epoch 273/300
# 22/22 - 0s - loss: 0.2639 - val_loss: 0.2608 - 252ms/epoch - 11ms/step
# Epoch 274/300
# 22/22 - 0s - loss: 0.2638 - val_loss: 0.2609 - 251ms/epoch - 11ms/step
# Epoch 275/300
# 22/22 - 0s - loss: 0.2635 - val_loss: 0.2605 - 268ms/epoch - 12ms/step
# Epoch 276/300
# 22/22 - 0s - loss: 0.2631 - val_loss: 0.2603 - 281ms/epoch - 13ms/step
# Epoch 277/300
# 22/22 - 0s - loss: 0.2632 - val_loss: 0.2601 - 241ms/epoch - 11ms/step
# Epoch 278/300
# 22/22 - 0s - loss: 0.2632 - val_loss: 0.2595 - 271ms/epoch - 12ms/step
# Epoch 279/300
# 22/22 - 0s - loss: 0.2629 - val_loss: 0.2595 - 361ms/epoch - 16ms/step
# Epoch 280/300
# 22/22 - 0s - loss: 0.2625 - val_loss: 0.2597 - 428ms/epoch - 19ms/step
# Epoch 281/300
# 22/22 - 0s - loss: 0.2621 - val_loss: 0.2585 - 387ms/epoch - 18ms/step
# Epoch 282/300
# 22/22 - 0s - loss: 0.2621 - val_loss: 0.2580 - 383ms/epoch - 17ms/step
# Epoch 283/300
# 22/22 - 0s - loss: 0.2617 - val_loss: 0.2576 - 385ms/epoch - 17ms/step
# Epoch 284/300
# 22/22 - 0s - loss: 0.2611 - val_loss: 0.2571 - 386ms/epoch - 18ms/step
# Epoch 285/300
# 22/22 - 0s - loss: 0.2609 - val_loss: 0.2566 - 438ms/epoch - 20ms/step
# Epoch 286/300
# 22/22 - 0s - loss: 0.2607 - val_loss: 0.2563 - 364ms/epoch - 17ms/step
# Epoch 287/300
# 22/22 - 0s - loss: 0.2605 - val_loss: 0.2560 - 271ms/epoch - 12ms/step
# Epoch 288/300
# 22/22 - 0s - loss: 0.2608 - val_loss: 0.2557 - 269ms/epoch - 12ms/step
# Epoch 289/300
# 22/22 - 0s - loss: 0.2598 - val_loss: 0.2546 - 251ms/epoch - 11ms/step
# Epoch 290/300
# 22/22 - 0s - loss: 0.2594 - val_loss: 0.2544 - 263ms/epoch - 12ms/step
# Epoch 291/300
# 22/22 - 0s - loss: 0.2584 - val_loss: 0.2540 - 288ms/epoch - 13ms/step
# Epoch 292/300
# 22/22 - 1s - loss: 0.2582 - val_loss: 0.2526 - 692ms/epoch - 31ms/step
# Epoch 293/300
# 22/22 - 1s - loss: 0.2576 - val_loss: 0.2520 - 539ms/epoch - 24ms/step
# Epoch 294/300
# 22/22 - 0s - loss: 0.2571 - val_loss: 0.2521 - 267ms/epoch - 12ms/step
# Epoch 295/300
# 22/22 - 0s - loss: 0.2568 - val_loss: 0.2503 - 306ms/epoch - 14ms/step
# Epoch 296/300
# 22/22 - 0s - loss: 0.2559 - val_loss: 0.2500 - 267ms/epoch - 12ms/step
# Epoch 297/300
# 22/22 - 0s - loss: 0.2556 - val_loss: 0.2494 - 273ms/epoch - 12ms/step
# Epoch 298/300
# 22/22 - 0s - loss: 0.2555 - val_loss: 0.2489 - 252ms/epoch - 11ms/step
# Epoch 299/300
# 22/22 - 0s - loss: 0.2546 - val_loss: 0.2496 - 280ms/epoch - 13ms/step
# Epoch 300/300
# 22/22 - 0s - loss: 0.2544 - val_loss: 0.2473 - 262ms/epoch - 12ms/step

# %%
plt.plot(lstm_autoencoder_history['loss'], linewidth=2, label='Train')
plt.plot(lstm_autoencoder_history['val_loss'], linewidth=2, label='Valid')
plt.legend(loc='upper right')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()

# %%
valid_x_predictions = lstm_autoencoder.predict(X_valid_scaled)
mse = np.mean(np.power(flatten(X_valid_scaled) - flatten(valid_x_predictions), 2), axis=1)

error_df = pd.DataFrame({'Reconstruction_error': mse,
                        'True_class': y_valid.tolist()})

precision_rt, recall_rt, threshold_rt = precision_recall_curve(error_df.True_class, error_df.Reconstruction_error)
plt.plot(threshold_rt, precision_rt[1:], label="Precision",linewidth=5)
plt.plot(threshold_rt, recall_rt[1:], label="Recall",linewidth=5)
plt.title('Precision and recall for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision/Recall')
plt.legend()
plt.show()
# Out:
# 10/10 [==============================] - 1s 9ms/step

# %%
test_x_predictions = lstm_autoencoder.predict(X_test_scaled)
mse = np.mean(np.power(flatten(X_test_scaled) - flatten(test_x_predictions), 2), axis=1)

error_df = pd.DataFrame({'Reconstruction_error': mse,
                        'True_class': y_test.tolist()})

threshold_fixed = 0.3
groups = error_df.groupby('True_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.Reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Break" if name == 1 else "Normal")
ax.hlines(threshold_fixed, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();
# Out:
# 14/14 [==============================] - 0s 6ms/step

# %%
pred_y = [1 if e > threshold_fixed else 0 for e in error_df.Reconstruction_error.values]

# %%
conf_matrix = confusion_matrix(error_df.True_class, pred_y)

plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
conf_matrix
# Out:
# array([[397,  37],
#        [  1,   1]])

# %%
# MSE Loss calculation
mse_loss = np.mean(mse)
print("MSE Loss:", mse_loss)
# Out:
# MSE Loss: 0.25340769209859376

# %%
false_pos_rate, true_pos_rate, thresholds = roc_curve(error_df.True_class, error_df.Reconstruction_error)
roc_auc = auc(false_pos_rate, true_pos_rate,)

plt.plot(false_pos_rate, true_pos_rate, linewidth=5, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1], linewidth=5)

plt.xlim([-0.01, 1])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Receiver operating characteristic curve (ROC)')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
